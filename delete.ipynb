# %%
import pandas as pd 
df=pd.read_csv("PROJECT_TIMELINE.csv")
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
pd.set_option("display.width",None)
pd.set_option("display.float_format",lambda x:f"{x:2f}")
pd.set_option("display.max_colwidth",None)
pd.set_option("display.max_colwidth",None)

# %%
df.head(1)
# Out:
#   Task ID                                                    Task Description  \
# 0    T001  Project Planning - Design hybrid vector search system architecture
#
#    Category     Status  \
# 0  Planning  Completed
#
#                                                                         Files Changed  \
# 0  docs/vector_search_design.md, docs/Production-Grade Hybrid Vector Search System.md
#
#   Time Taken  \
# 0    2 hours
#
#                                                                                                             Notes
# 0  Initial architecture design with Qdrant, Supabase, FastAPI. Defined chunking strategy (400 tokens, 40 overlap)

# %%
df.to_csv("PROJECT_TIMELINE.csv",index=False)

# %%
df["Time Taken"].to_json
# Out:
# <bound method NDFrame.to_json of 0       2 hours
# 1        1 hour
# 2     1.5 hours
# 3        1 hour
# 4        1 hour
# 5     1.5 hours
# 6       2 hours
# 7       2 hours
# 8     1.5 hours
# 9       3 hours
# 10       1 hour
# 11      2 hours
# 12      2 hours
# 13      3 hours
# 14      2 hours
# 15      2 hours
# 16    1.5 hours
# 17      4 hours
# 18       1 hour
# 19    1.5 hours
# 20       1 hour
# 21       1 hour
# 22      30 mins
# 23       1 hour
# 24       1 hour
# 25       1 hour
# 26    1.5 hours
# 27       1 hour
# 28      2 hours
# 29      2 hours
# 30    1.5 hours
# 31    1.5 hours
# 32      2 hours
# 33      4 hours
# 34       1 hour
# 35       1 hour
# 36      15 mins
# 37       1 hour
# Name: Time Taken, dtype: object>
